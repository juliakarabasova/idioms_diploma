# %%
from pathlib import Path
import os
import json
from pymystem3 import Mystem

# %%
def get_text(path):
    files = {}
    whole_text = ''
    for file in Path(path).glob('*_processed.txt'):
        file_id = str(file).split('\\')[-1].split('_')[0]
        with open(file, 'r', encoding='utf-8') as f:
            files[int(file_id)] = f.read()
            whole_text += files[int(file_id)] + ' '
    return files, whole_text


def parse(text):
    tokens = []
    result = Mystem().analyze(text)

    for i, word in enumerate(result):
        if not word.get('analysis', 0) or not word.get('text', 0):
            continue

        word_base = word['analysis'][0]
        if not word_base.get('lex', 0) or not word_base.get('gr', 0):
            continue

        tokens.append(word['analysis'][0]['lex'])
    return tokens


def get_idioms():
    with open(r"D:\Python\diploma\idioms_collection.json", 'r', encoding='utf-8') as f:
        idioms = json.load(f)
    return idioms


def dump_idioms(idioms):
    with open(r"D:\Python\diploma\idioms_lemmatized.json", 'a', encoding='utf-8') as f:
        for idiom in idioms:
            json.dump(idiom, f, ensure_ascii=False, indent=4)


def lemmatize_idioms(idioms):
    idioms_lem = []
    for i, idiom in enumerate(idioms[::-1]):
        if i in range(3801):
            continue
        idioms_lem.append({'phrase': []})
        for phrase in idiom['phrase']:
            idioms_lem[-1]['phrase'].append(' '.join(parse(phrase)))
        idioms_lem[-1].update({key: value for key, value in idiom.items() if key != 'phrase'})
        if i % 100 == 0 and i > 0:
            print(f'-- {i} --\nLast idiom to be processed:\n{idioms_lem[-1]}\n\n')
            dump_idioms(idioms_lem[-100:])
    return idioms_lem

# %%
idioms = get_idioms()
idioms_lem = lemmatize_idioms(idioms)
print(*idioms_lem[-10], sep='\n\n')
dump_idioms()
# Out:
# -- 100 --
# Last idiom to be processed:
# {'phrase': ['с ум'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Рассудительно, разумно, с пониманием.', 'abbr': [], 'examples': [{'text': 'Когда перенимать с умом, тогда не чудо и пользу от того сыскать, а без ума перенимать, и боже сохрани, как худо! Крылов.', 'source': ''}]}]}
#
#
# -- 200 --
# Last idiom to be processed:
# {'phrase': ['за один спасибо сделать что н'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Даром, без всякой выгоды.', 'abbr': ['разг', 'фам'], 'examples': [{'text': 'Кто же будет за одно спасибо стараться.', 'source': ''}]}]}
#
#
# -- 300 --
# Last idiom to be processed:
# {'phrase': ['саврас без узда или безуздый саврас молодой мужчина склонный к кутеж бесшабашный разгул преимущий о купеческий сынок'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': '', 'abbr': ['разг', 'перен'], 'examples': []}]}
#
#
# -- 400 --
# Last idiom to be processed:
# {'phrase': ['проливать проливать слеза'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Заплакать, поплакать.', 'abbr': [], 'examples': [{'text': 'Над его письмами она пролила немало слез.', 'source': ''}]}]}
#
#
# -- 500 --
# Last idiom to be processed:
# {'phrase': ['покончить с себя или с жизнь или покончить расчет с жизнь или покончить жизнь самоубийство'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Насильственно прекратить свою жизнь.', 'abbr': ['ритор'], 'examples': [{'text': 'Уж лучше же я сам с собой покончу. Тургенев.', 'source': ''}]}]}
#
#
# -- 600 --
# Last idiom to be processed:
# {'phrase': ['как у христос за пазуха житьрвзг'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Очень хорошо, вольготно.', 'abbr': ['устар'], 'examples': [{'text': 'За батюшкой, за матушкой, как у Христа за пазухой, жила я, молодцы! Некрасов.', 'source': ''}]}]}
#
#
# -- 700 --
# Last idiom to be processed:
# {'phrase': ['нет и нет или нет да нет или нет как нет'], 'semantics': [{'dictionary': 'Volkova', 'role': ['кого-чего', 'разг'], 'meaning': 'Не имеется налицо, не существует вовсе, употребляется для большей выразительности.', 'abbr': [], 'examples': [{'text': 'Но день протек, и нет ответа, другой настал: все нет как нет. А. Пушкин.', 'source': ''}]}]}
#
#
# -- 800 --
# Last idiom to be processed:
# {'phrase': ['легкость в мысль'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Легкомыслие, несерьезность .', 'abbr': ['шутл'], 'examples': []}]}
#
#
# -- 900 --
# Last idiom to be processed:
# {'phrase': ['иметь цель задачейилить иметь цель задача'], 'semantics': [{'dictionary': 'Volkova', 'role': ['что', 'с инф'], 'meaning': 'Стремиться к чему- н., добиваться чего-н. (о лице).', 'abbr': ['книжн'], 'examples': [{'text': 'Нансен имел задачей достижение северного полюса или имел задачу — достичь сев. полюса.', 'source': ''}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Быть направленным, клониться к какой-н. цели (о предметах, отвлеченных понятиях).', 'abbr': [], 'examples': [{'text': 'Забастовка имела целью повышение заработной платы.', 'source': ''}]}]}
#
#
# -- 1000 --
# Last idiom to be processed:
# {'phrase': ['за железный решетка'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'В тюрьме.', 'abbr': ['ритор'], 'examples': [{'text': 'Несколько лет провел за железной решеткой.', 'source': ''}]}]}
#
#
# -- 1100 --
# Last idiom to be processed:
# {'phrase': ['грешный дело вводный слово'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'К сожалениюхотя это и не хорошо.', 'abbr': ['разг'], 'examples': [{'text': 'Я, грешным делом, люблю выпить рюмочку перед обедом.', 'source': ''}]}]}
#
#
# -- 1200 --
# Last idiom to be processed:
# {'phrase': ['вот-вот норма'], 'semantics': [{'dictionary': 'Volkova', 'role': [], 'meaning': 'Еще немного и..., один момент и... сию минуту.', 'abbr': ['разг'], 'examples': [{'text': 'Так плохо держится, что вот-вот упадет.', 'source': 'Подождите, он вот-вот приедет'}]}]}
#
#
# -- 1300 --
# Last idiom to be processed:
# {'phrase': ['брать на порука право'], 'semantics': [{'dictionary': 'Volkova', 'role': ['кого'], 'meaning': 'Ручаться за -н., что он не уклонится от следствия, суда.', 'abbr': [], 'examples': [{'text': 'Преступника взяли на поруки.', 'source': ''}]}]}
#
#
# -- 1400 --
# Last idiom to be processed:
# {'phrase': ['сохранять присутствие дух'], 'semantics': [{'dictionary': 'Myurrey', 'role': [], 'meaning': '', 'abbr': [], 'examples': []}]}
#
#
# -- 1500 --
# Last idiom to be processed:
# {'phrase': ['запевать на другой лад'], 'semantics': [{'dictionary': 'Myurrey', 'role': [], 'meaning': '', 'abbr': [], 'examples': []}]}
#
#
# -- 1600 --
# Last idiom to be processed:
# {'phrase': ['шарик зайти за ролик'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['у кого'], 'meaning': '', 'abbr': ['прост', 'шутл'], 'examples': [{'text': 'Настолько всё смешалось в голове, настолько шарики зашли в нём за ролики, что он чуть было не подумал Кто это? знакомая какая-то!', 'source': 'В. Распутин, Пожар'}]}]}
#
#
# -- 1700 --
# Last idiom to be processed:
# {'phrase': ['хотеть верить хотеть нет'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['погов'], 'examples': [{'text': 'Знаете, я с каждым днём всё более убеждаюсь, что мы живём накануне величайшего торжества, и мне хотелось бы дожить, самому участвовать. Хотите верьте, хотите нет, но, по-моему, подрастает теперь замечательное поколение.', 'source': 'А. Чехов, Три года'}]}]}
#
#
# -- 1800 --
# Last idiom to be processed:
# {'phrase': ['трещать как сорока'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['неодобрит', 'разг'], 'examples': []}]}
#
#
# -- 1900 --
# Last idiom to be processed:
# {'phrase': ['стелиться коврик', 'стелиться ковер'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['перед кем'], 'meaning': '', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': ['перед кем'], 'meaning': '', 'abbr': ['презрит'], 'examples': []}]}
#
#
# -- 2000 --
# Last idiom to be processed:
# {'phrase': ['слишком жирно'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Если любить всех девушек, которых я встречаю, живя под луной, то не хватит сердца, и слишком жирно...', 'source': 'А. Чехов, Драма на охоте'}]}]}
#
#
# -- 2100 --
# Last idiom to be processed:
# {'phrase': ['с непокрытый голова'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': [], 'examples': []}]}
#
#
# -- 2200 --
# Last idiom to be processed:
# {'phrase': ['против рожон не попереть'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['посл'], 'examples': [{'text': 'Так, брат... Выходит, ты и в самом деле вырос... Рановато, конечно, в пятнадцать лет всю свою судьбу решать, но против рожна, видно, не попрёшь...', 'source': 'Л. Соболев, Зелёный луч'}]}]}
#
#
# -- 2300 --
# Last idiom to be processed:
# {'phrase': ['понятный дело'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['прост'], 'examples': []}]}
#
#
# -- 2400 --
# Last idiom to be processed:
# {'phrase': ['по блат'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['достать, получить и т. п. что-либо'], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Самая выгодная работа в магазине, но туда только по блату можно попасть.', 'source': 'И. Грекова, Кафедра'}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Незаконным способом.', 'abbr': ['нов', 'прост', 'вульг'], 'examples': [{'text': 'Получить что-н. по блату в кооперативе.', 'source': ''}]}]}
#
#
# -- 2500 --
# Last idiom to be processed:
# {'phrase': ['оставлять на совесть'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['чьей'], 'meaning': '', 'abbr': [], 'examples': [{'text': 'Злые языки в . Половинкине видели просто фаворита Раисы Павловны.., но мы такую догадку оставим на их совести.', 'source': 'Д. Мамин-Сибиряк, Горное гнездо'}]}]}
#
#
# -- 2600 --
# Last idiom to be processed:
# {'phrase': ['нерв шалить'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['у кого'], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'За окном что-то зашуршало, хрустнула ветка, раздался чавкающий звук. Харт замер у окна. Никого. Нервы шалят.', 'source': 'В. Черняк, Час пробил'}]}]}
# -- 2700 --
# Last idiom to be processed:
# {'phrase': ['не видать как свой затылок'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['чего'], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Вижу, Азамат, что тебе больно понравилась эта лошадь а не видать тебе её как своего затылка!..', 'source': 'М. Лермонтов, Герой нашего времени'}]}]}
#
#
# -- 2800 --
# Last idiom to be processed:
# {'phrase': ['на ноль'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['быть, сидеть и т. п.'], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Ждать помощи от отца ей не приходится  он сам на нуле.', 'source': 'В. Черняк, Час пробил'}]}]}
#
#
# -- 2900 --
# Last idiom to be processed:
# {'phrase': ['ловить на себя взгляд'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['чей, кого'], 'meaning': '', 'abbr': [], 'examples': [{'text': 'Шамет всё чаще ловил на себе недоумевающий взгляд девочки.', 'source': 'К. Паустовский, Золотая роза'}]}]}
#
#
# -- 3000 --
# Last idiom to be processed:
# {'phrase': ['клубок в горло стоять'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': [], 'examples': [{'text': 'Слёз не было, но что-то жгучее щипало глаза, и в горле стоял сухой и колючий клубок...', 'source': 'А. Куприн, Молох'}]}]}
#
#
# -- 3100 --
# Last idiom to be processed:
# {'phrase': ['как бог'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['делать что-либо'], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Я вспомнил Женькин вариант заголовка и вписал его, зачеркнув свой Женька вообще давал заголовки, как бог.', 'source': 'Л. Жуховицкий, Остановиться, оглянуться...'}]}]}
#
#
# -- 3200 --
# Last idiom to be processed:
# {'phrase': ['затягивать пояс'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'Эх, не впервой затягивать пояс потуже. Извернёмся, то ли бывало.', 'source': 'В. Панова, Ясный берег'}]}]}
#
#
# -- 3300 --
# Last idiom to be processed:
# {'phrase': ['еще туда-сюда'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'А лечили как?  Тут и лечили, только лекарствов, надо быть, не было никаких, а чем бабушка вздумает, тем и помогает... Коли другой в город сноровит  этому ещё туда-сюда, а здесь-то, по деревням,  эге, как залечивали!', 'source': 'Д. Фурманов, Чапаев'}]}]}
#
#
# -- 3400 --
# Last idiom to be processed:
# {'phrase': ['для затравка'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Теперь для затравки нужна небольшая встречная откровенность.', 'source': 'С. Есин, Техника речи'}]}]}
#
#
# -- 3500 --
# Last idiom to be processed:
# {'phrase': ['грести лопата'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': 'О деньгах.', 'abbr': ['прост'], 'examples': [{'text': 'Где может быть сейчас Роллинг?  Как где? Конечно, в Париже. Ворочает прессой. У него сейчас большое наступление на химическом фронте. Деньги лопатой загребает.', 'source': 'А. Толстой, Гиперболоид инженера Гарина'}]}]}
#
#
# -- 3600 --
# Last idiom to be processed:
# {'phrase': ['выдавать на-гора'], 'semantics': [{'dictionary': 'Kveselevich', 'role': ['что'], 'meaning': '', 'abbr': ['иpoн'], 'examples': [{'text': 'Старик очень старается, понимает, что уже пора бы что-то и выдать на-гора, выискивает в кладовых своей памяти бог знает какие детали и впечатления, но всё равно его спутница-гурманка морщится  пресно.', 'source': 'М. Попов, Ошибка рецензента'}]}]}
#
#
# -- 3700 --
# Last idiom to be processed:
# {'phrase': ['возвращаться к разбивать корыто'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': [], 'examples': []}]}
#
#
# -- 3800 --
# Last idiom to be processed:
# {'phrase': ['в один карман блоха на аркан а в другой вошь на цепь'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['груб', 'грубо-прост', 'иpoн', 'погов'], 'examples': [{'text': 'У него в одном кармане блоха на аркане, а в другом  вошь на цепи, вот и всё его богатство...', 'source': 'М. Шолохов, Поднятая целина'}]}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6756/2770454699.py in <module>
#       1 idioms = get_idioms()
# ----> 2 idioms_lem = lemmatize_idioms(idioms)
#       3 print(*idioms_lem[-10], sep='\n\n')
#       4 dump_idioms()
#
# ~\AppData\Local\Temp/ipykernel_6756/903898824.py in lemmatize_idioms(idioms)
#      43         idioms_lem.append({'phrase': []})
#      44         for phrase in idiom['phrase']:
# ---> 45             idioms_lem[-1]['phrase'].append(' '.join(parse(phrase)))
#      46         idioms_lem[-1].update({key: value for key, value in idiom.items() if key != 'phrase'})
#      47         if i % 100 == 0 and i > 0:
#
# ~\AppData\Local\Temp/ipykernel_6756/903898824.py in parse(text)
#      12 def parse(text):
#      13     tokens = []
# ---> 14     result = Mystem().analyze(text)
#      15
#      16     for i, word in enumerate(result):
#
# D:\anaconda\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     253         result = []
#     254         for line in text.splitlines():
# --> 255             result.extend(self._analyze_impl(line))
#     256         return result
#     257
#
# D:\anaconda\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     316             self._procin.write(_NL)
#     317
# --> 318             out, _ = self._proc.communicate()
#     319             self._proc = None
#     320             try:
#
# D:\anaconda\lib\subprocess.py in communicate(self, input, timeout)
#     962
#     963             try:
# --> 964                 stdout, stderr = self._communicate(input, endtime, timeout)
#     965             except KeyboardInterrupt:
#     966                 # https://bugs.python.org/issue25942
#
# D:\anaconda\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1294             # calls communicate again.
#    1295             if self.stdout is not None:
# -> 1296                 self.stdout_thread.join(self._remaining_time(endtime))
#    1297                 if self.stdout_thread.is_alive():
#    1298                     raise TimeoutExpired(self.args, orig_timeout)
#
# D:\anaconda\lib\threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# D:\anaconda\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# -- 3800 --

# %%
idioms = get_idioms()
idioms_lem = lemmatize_idioms(idioms)
# Out:
# -- 3900 --
# Last idiom to be processed:
# {'phrase': ['много все на свет'], 'semantics': [{'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'Этот-то букет больше всего на свете злил Кешу. Он не мог и не хотел понять, зачем ей нужен был этот дурацкий букет...', 'source': 'Г. Семёнов, К зиме, минуя осень'}]}]}
#
#
# -- 4000 --
# Last idiom to be processed:
# {'phrase': ['язык не повертываться у кто сказать спрашивать'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Нет решимости.', 'abbr': [], 'examples': []}]}
#
#
# -- 4100 --
# Last idiom to be processed:
# {'phrase': ['черт знать кто или что какой куда'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Неизвестно кто (или что, какой, куда и т. п.).', 'abbr': ['прост'], 'examples': []}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'О ком-либо, чем-либо очень плохом, дурном.', 'abbr': [], 'examples': []}]}
#
#
# -- 4200 --
# Last idiom to be processed:
# {'phrase': ['фря какой'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Возглас возмущения по поводу капризного поведения кого-либо.', 'abbr': ['презрит', 'неодобрит'], 'examples': []}]}
#
#
# -- 4300 --
# Last idiom to be processed:
# {'phrase': ['молчать как убитый'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Молчать упорно, не говорить ни слова.', 'abbr': [], 'examples': []}]}
#
#
# -- 4400 --
# Last idiom to be processed:
# {'phrase': ['из другой или разный тесто'], 'semantics': [{'dictionary': 'Fedosov', 'role': [' кто'], 'meaning': 'О людях, резко отличающихся друг от друга (по характеру, взглядам и т. п.).', 'abbr': [], 'examples': []}]}
#
#
# -- 4500 --
# Last idiom to be processed:
# {'phrase': ['стыдливый кусок кусочек'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Последний кусок на блюде, который каждый из сидящих за столом стесняется взять.', 'abbr': [], 'examples': []}]}
#
#
# -- 4600 --
# Last idiom to be processed:
# {'phrase': ['как спичка'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Очень худ, тощ (о человеке).', 'abbr': [], 'examples': []}]}
#
#
# -- 4700 --
# Last idiom to be processed:
# {'phrase': ['не сметь', 'не сметь'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Употребляется как форма строгого запрещения что-либо делать.', 'abbr': [], 'examples': []}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Употребляется как форма строгого запрещения что-н. делать.', 'abbr': [], 'examples': [{'text': 'Не смей ходить. Не смейте прекословить.', 'source': ''}]}]}
#
#
# -- 4800 --
# Last idiom to be processed:
# {'phrase': ['умирать свой смерть'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Умереть естественной смертью.', 'abbr': [], 'examples': []}]}
#
#
# -- 4900 --
# Last idiom to be processed:
# {'phrase': ['римский нос'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Крупный, правильной формы нос с горбинкой.', 'abbr': [], 'examples': []}]}
#
#
# -- 5000 --
# Last idiom to be processed:
# {'phrase': ['на проба', 'на проба взять', 'на проба давать'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Для проверки, испытания, оценки.', 'abbr': [], 'examples': []}]}
#
#
# -- 5100 --
# Last idiom to be processed:
# {'phrase': ['понижать голос или тон'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Сказать тише обычного, тише, чем говорил до этого.', 'abbr': [], 'examples': []}]}
#
#
# -- 5200 --
# Last idiom to be processed:
# {'phrase': ['плетение словеса'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'О многословном вычурном стиле (обычно при бедном содержании).', 'abbr': ['иpoн'], 'examples': []}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['иpoн', 'книжн'], 'examples': []}]}
#
#
# -- 5300 --
# Last idiom to be processed:
# {'phrase': ['открытый вопрос'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Нерешенный вопрос.', 'abbr': [], 'examples': []}]}
#
#
# -- 5400 --
# Last idiom to be processed:
# {'phrase': ['нужда мало'], 'semantics': [{'dictionary': 'Fedosov', 'role': [' кому'], 'meaning': 'Нет дела, не касается кого-либо.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': ['кому до чего'], 'meaning': '', 'abbr': ['устар'], 'examples': [{'text': 'Мавра Тарасовна. Ну, мне до этих твоих меланхолиев нужды мало.', 'source': 'А. Островский, Правда  хорошо, а счастье лучше'}]}]}
#
#
# -- 5500 --
# Last idiom to be processed:
# {'phrase': ['невзвидеть свет или день'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Об очень сильной степени какого-либо ощущения, чувства (боли, страха, гнева и т. п.).', 'abbr': [], 'examples': []}]}
#
#
# -- 5600 --
# Last idiom to be processed:
# {'phrase': ['молодец против среди на овца а против на молодец и сам овца'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Говорится о том, кто смел, самоуверен только среди тех, кто слабее, ниже в каком-либо отношении.', 'abbr': [], 'examples': []}]}
#
#
# -- 5700 --
# Last idiom to be processed:
# {'phrase': ['маланьин счет', 'маланьин счет'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'О неумелом, неправильном счете.', 'abbr': ['прост'], 'examples': []}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['иpoн', 'прост'], 'examples': []}]}
#
#
# -- 5800 --
# Last idiom to be processed:
# {'phrase': ['попадать или угождать в лапа'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Быть пойманным, схваченным кем-либо.', 'abbr': [], 'examples': []}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'Оказаться в чьей-либо власти, в зависимости от кого-либо.', 'abbr': [], 'examples': []}]}
#
#
# -- 5900 --
# Last idiom to be processed:
# {'phrase': ['крайний мера'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Самые решительные, самые суровые меры.', 'abbr': [], 'examples': []}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Самые решительные, самые суровые меры.', 'abbr': [], 'examples': [{'text': 'Будут приняты крайние меры.', 'source': ''}]}]}
#
#
# -- 6000 --
# Last idiom to be processed:
# {'phrase': ['в клок разрывать разнести'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'На очень мелкие части.', 'abbr': [], 'examples': []}]}
#
#
# -- 6100 --
# Last idiom to be processed:
# {'phrase': ['как будто словно иголка в стог сено исчезать затериваться'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'О ком-либо, чем-либо, кого (или что) невозможно найти.', 'abbr': [], 'examples': []}]}
#
#
# -- 6200 --
# Last idiom to be processed:
# {'phrase': ['не сегодня или не нынче завтра'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Очень скоро, в ближайшем будущем.', 'abbr': [], 'examples': []}]}
#
#
# -- 6300 --
# Last idiom to be processed:
# {'phrase': ['много о себя думать'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Быть слишком высокого мнения о себе.', 'abbr': [], 'examples': []}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Быть слишком высокого мнения о себе.', 'abbr': ['разг'], 'examples': []}]}
#
#
# -- 6400 --
# Last idiom to be processed:
# {'phrase': ['дело время а потеха час', 'дело время потеха час'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Основное время делам, а забавам, веселью только досуг.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['посл'], 'examples': [{'text': 'Ну ладно, пожелаю здоровьечка!  сказал кучер Снимщиков.  Делу, как говорится, время, а потехе час.', 'source': 'Ю. Герман, Дело, которому ты служишь'}]}]}
#
#
# -- 6500 --
# Last idiom to be processed:
# {'phrase': ['по горячий след по горячий след'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'По свежим следам.', 'abbr': [], 'examples': []}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'Тотчас же, после какого-либо события.', 'abbr': [], 'examples': []}]}
#
#
# -- 6600 --
# Last idiom to be processed:
# {'phrase': ['гнаться по пята'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Преследовать кого-либо, не отставая.', 'abbr': [], 'examples': []}]}
#
#
# -- 6700 --
# Last idiom to be processed:
# {'phrase': ['выпяливать глаз на кто что'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Уставиться на кого-либо, что-либо широко раскрытыми глазами.', 'abbr': ['груб', 'прост'], 'examples': []}]}
# -- 6800 --
# Last idiom to be processed:
# {'phrase': ['взять на себя воля'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Избаловаться, перестать слушаться старших.', 'abbr': [], 'examples': []}]}
#
#
# -- 6900 --
# Last idiom to be processed:
# {'phrase': ['вздыхать некогда', 'дохнуть некогда', 'дыхнуть некогда'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'О чрезвычайной занятости.', 'abbr': [], 'examples': []}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'Очень занят, нагружен чем-либо.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'А разве я хуже мужчины работаю? Или я сына плохого вырастила? До сих пор мне дохнуть было некогда...', 'source': 'А. Коптяева, Дерзание'}]}, {'examples': [{'text': 'Да полно тебе, сватушка, церемониться, — говорила старостиха, — зайди, родная… — Право, неколи, — отвечала Петровна… — Таперича дыхнуть некогда. Ребятишки ждут тоже, сама знаешь', 'source': 'Н. Успенский. Сцены из сельского праздника'}], 'abbr': ['прост', 'экспрес'], 'meaning': 'Кто-либо очень занят, перегружен делами, работой; не имеет даже короткого отдыха.', 'dictionary': 'Fedorov'}]}
#
#
# -- 7000 --
# Last idiom to be processed:
# {'phrase': ['на бум бум'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'В расчете на случайную удачу.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': ['делать что-либо'], 'meaning': '', 'abbr': ['неодобрит', 'прост'], 'examples': [{'text': 'А вы? Вам сказали или тоже на бум-бум едете?', 'source': 'В. Шукшин, Медик Володя'}]}]}
#
#
# -- 7100 --
# Last idiom to be processed:
# {'phrase': ['бог напитывать никто не видать а кто и видеть тот не обижать'], 'semantics': [{'dictionary': 'Fedosov', 'role': [], 'meaning': 'Говорится после окончания еды.', 'abbr': [], 'examples': []}]}
#
#
# -- 7200 --
# Last idiom to be processed:
# {'phrase': ['язык чесаться'], 'semantics': [{'examples': [{'text': 'Это была та минута в обедах с речами, когда у многих чешется язык, но разбирает робость', 'source': 'П. Боборыкин. На ущербе'}], 'abbr': ['разг', 'иpoн'], 'meaning': 'Кто-либо не может утерпеть, удержаться от разговора, от высказывания.', 'role': ['у кого'], 'dictionary': 'Fedorov'}, {'dictionary': 'Fedosov', 'role': [' у кого'], 'meaning': 'О большом, неудержимом желании высказаться, высказать свое мнение.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': ['у кого'], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'Баташов. Роль странная, все говорят, а ты сидишь здесь, молчишь, мысли бегают, язык чешется, вот и втиснулся.', 'source': 'М. Шатров, Диктатура совести'}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Есть желание, хочется сказать, высказаться.', 'abbr': [], 'examples': [{'text': 'У меня давно язык чешется рассказать про это.', 'source': ''}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Есть желание, хочется сказать, высказаться.', 'abbr': ['разг'], 'examples': [{'text': 'Так и чешется язык во всем признаться,', 'source': ''}]}]}
#
#
# -- 7300 --
# Last idiom to be processed:
# {'phrase': ['шар на лоб вылезать'], 'semantics': [{'examples': [{'text': 'А ты бы полез за гранатой? — Приказали б — и полез. — «Полез»! — передразнил его ефрейтор. — У самого от страха шары на лоб вылезли', 'source': 'В. Курочкин. На войне как на войне'}], 'abbr': ['грубо-прост', 'экспрес'], 'meaning': 'Кто-либо испытывает страх, испуг, боль и т..', 'role': ['кого'], 'dictionary': 'Fedorov'}]}
#
#
# -- 7400 --
# Last idiom to be processed:
# {'phrase': ['что за нужда'], 'semantics': [{'examples': [{'text': '«Ну что за нужда, что она мне не верит, — думала Марья Александровна… — только бы ловчее намекнуть, о чём мне прямо нельзя говорить?»', 'source': 'Достоевский. Дядюшкин сон'}], 'abbr': ['разг'], 'meaning': 'Не имеет значения, безразлично.', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['устар'], 'examples': [{'text': 'Но что за нужда, что она мне не верит,  думала Марья Александровна,  только бы её заставить задуматься!', 'source': 'Ф. Достоевский, Дядюшкин сон'}]}]}
#
#
# -- 7500 --
# Last idiom to be processed:
# {'phrase': ['черный краска', 'в черный краска'], 'semantics': [{'examples': [{'text': 'При мне у Императрицы за столом описывал он вас весьма чёрными красками, называя вас дерзким, коварным и тому подобное', 'source': 'Державин. Записки'}, {'text': 'Очертил Бездомный главное действующее лицо своей поэмы, то есть Иисуса, очень чёрными красками, и тем не менее всю поэму приходилось, по мнению редактора, писать заново', 'source': 'М. Булгаков. Мастер и Маргарита'}], 'abbr': ['экспрес'], 'meaning': 'В мрачном свете; хуже, чем есть на самом деле (описывать, очерчивать и т. п. кого или что).', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': ['описывать, рисовать, представлять и т. п. кого-либо, что-либо'], 'meaning': '', 'abbr': [], 'examples': []}]}
#
#
# -- 7600 --
# Last idiom to be processed:
# {'phrase': ['царский двор'], 'semantics': [{'examples': [{'text': 'Рядом со словами «Кондитерская фабрика Х. П. Воскобойникова» вспыхнут царский герб и новые слова: «Поставщик двора его императорского величества»… Да это же чудо! Была у человека фабричонка… а теперь он поставщик царского двора', 'source': 'Н. Ляшко. Сладкая каторга'}], 'abbr': ['устар'], 'meaning': 'Царь и его приближённые, придворные.', 'dictionary': 'Fedorov'}]}
#
#
# -- 7700 --
# Last idiom to be processed:
# {'phrase': ['хорошенький хороший дело'], 'semantics': [{'examples': [], 'abbr': ['разг', 'неодобрит'], 'meaning': 'Не одобряю то, что произошло, случилось; так ли на самом деле, в действительности? —  (в. беляев. старая крепость).', 'role': ['Погоди, а что у тебя с пальцем? — Да вот, стукнул нечаянно… — Хорошее дело — стукнул! Он распух у тебя, как поп на пасху'], 'dictionary': 'Fedorov'}]}
#
#
# -- 7800 --
# Last idiom to be processed:
# {'phrase': ['хам сын'], 'semantics': [{'examples': [{'text': 'Потише, господа! — сказал я, вспыхнув тоже. «Как! что… Зазнался, хамов сын»', 'source': 'Некрасов. Ночлеги'}], 'abbr': ['устар', 'грубо-прост'], 'meaning': 'Бранное выражение, употребляемое применительно к лицу мужского пола.', 'dictionary': 'Fedorov'}]}
#
#
# -- 7900 --
# Last idiom to be processed:
# {'phrase': ['укорачивать рука', 'укорачивать рука'], 'semantics': [{'examples': [{'text': 'Почал он её бить. Долго он её так таскал, а она — выть… — Эх, черти! Да неужто ж ему, подлецу, никто рук не укоротит, а?', 'source': 'А. Караваева. Медвежатное'}], 'abbr': ['прост', 'экспрес'], 'meaning': 'Не давать, запрещать кому-либо бесчинствовать.', 'role': ['кому'], 'dictionary': 'Fedorov'}, {'dictionary': 'Fedosov', 'role': [' кому'], 'meaning': 'Запретить кому-либо бесчинствовать, драться.', 'abbr': [], 'examples': []}]}
#
#
# -- 8000 --
# Last idiom to be processed:
# {'phrase': ['тьфу ты пропасть', 'фу ты пропасть', 'тьфу пропасть'], 'semantics': [{'examples': [{'text': 'Тьфу ты пропасть, — пробормотал он, плюнув в воду, — какая оказия! А всё ты, старый чёрт!.. что это у тебя за лодка!', 'source': 'Тургенев. Льгов'}], 'abbr': ['разг', 'экспрес'], 'meaning': 'Выражение досады, возмущения, раздражения.', 'dictionary': 'Fedorov'}, {'examples': [{'text': 'Славная бекеша у Ивана Ивановича! Отличнейшая! А какие смушки! Фу ты пропасть, какие смушки! сизые с морозом', 'source': 'Гоголь. Повесть о том, как поссорился Иван Иванович…'}], 'abbr': ['разг', 'экспрес'], 'meaning': 'Выражение восхищения, удивления и т. п.', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['неодобрит', 'прост'], 'examples': [{'text': 'Тьфу ты пропасть!  пробормотал он, плюнув в воду  какая оказия!', 'source': 'И. Тургенев, Записки охотника'}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Употребляется при выражении досады, раздражения в знач.: вот досада, черт возьми.', 'abbr': ['разг'], 'examples': [{'text': '— Очки не действуют никак. "Тьфу, пропасть!", говорит она: "и тот дурак, кто слушает людских всех врак". Крылов.', 'source': ''}]}]}
#
#
# -- 8100 --
# Last idiom to be processed:
# {'phrase': ['толоконный брюхо'], 'semantics': [{'examples': [{'text': 'Этот шельма Тришка обозвал старика на чём свет стоит! «И толоконное, говорит, ты брюхо!». — А-а-а! Взмолился! Ноги-то, видно, отморозил, толоконное брюхо!', 'source': 'В. Слепцов. Отрывки из дорожных заметок пешехода'}], 'abbr': ['устар', 'пренебр'], 'meaning': 'Порицание за промах, недальновидный поступок, за грубость и т. п.', 'dictionary': 'Fedorov'}]}
# -- 8200 --
# Last idiom to be processed:
# {'phrase': ['сыр-бор', 'сыр-бор гореть'], 'semantics': [{'examples': [{'text': 'Ежели хочешь знать, тёзка Егорий, интеллектуалы эти у нас вот где сидят! — артист хлопнул себя ладошкою по шее. — Из-за них, понимаешь, весь сыр-бор горит', 'source': 'М. Юдалевич. Пятый год'}, {'text': 'Теперь-то дошло до меня, что к чему, из-за чего у них сыр-бор. Залётный Эдик высмотрел доярку Нюру — знатную работницу, с орденами, премиями и сманил к себе', 'source': 'А. Иванов. Филя Тропочкин'}], 'meaning': 'Происходит что-либо из-за кого-либо или по какой-то причине.', 'role': ['из-за кого, чего'], 'dictionary': 'Fedorov', 'abbr': []}]}
#
#
# -- 8300 --
# Last idiom to be processed:
# {'phrase': ['стоять один нога во гроб в гроб'], 'semantics': [{'examples': [{'text': '— Я — старик, одной ногой во гробе стою, не чаю и завтрашнего утра увидеть, однако ж не плачусь. А ты — воевода, для чего ж срамишься?', 'source': 'Ю. Герман. Россия молодая'}], 'abbr': ['устар', 'экспрес'], 'meaning': 'Доживать свою жизнь, быть близким к смерти. обычно о больном или старом человеке.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8400 --
# Last idiom to be processed:
# {'phrase': ['средний число'], 'semantics': [{'examples': [{'text': 'Река средним числом на каждых двух верстах мелководна или засорена', 'source': 'Чехов. Остров Сахалин'}, {'text': 'Доставил ли вам Юргенсон на городскую квартиру мои старинные польские романсики? Им, средним числом, лет по пятьдесят', 'source': 'Ц. Кюи. Письмо М. С. Керзиной, 13 июня 1902'}], 'abbr': ['устар'], 'meaning': 'Приблизительно.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8500 --
# Last idiom to be processed:
# {'phrase': ['содом и гоморра гоморра'], 'semantics': [{'examples': [{'text': 'Вот тут и ахнул кто-то из матросов: «Эй! Ваше благоутробие! Заткнись!» А потом и пошло! Крики: «Вон…». Свист в четыре пальца, — содом и гоморра!', 'source': 'Сергеев-Ценский. Утренний взрыв'}], 'abbr': ['экспрес'], 'meaning': 'Суматоха, беспорядок; шум и гам; неразбериха.', 'dictionary': 'Fedorov'}, {'examples': [{'text': 'Что это? помилуйте, до чего безнравственность доходит: по ночам бегают, трубку курят… Одна пьяная пришла. Содом и гоморр!', 'source': 'Писемский. Тысяча душ'}], 'abbr': ['экспрес'], 'meaning': 'Кутёж, разврат где-либо.', 'dictionary': 'Fedorov'}, {'examples': [], 'abbr': ['экспрес'], 'meaning': ': толковый словарь русского языка / под ред. проф. д. н. ушакова. — м, 1940. — т. 4. — с. 354. ашукин н. с., ашукина м. г. крылатые слова. — м., 1960. — с. 570.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8600 --
# Last idiom to be processed:
# {'phrase': ['смотреть в корень'], 'semantics': [{'examples': [{'text': 'Надо смотреть в корень и искать в каждом явлении причину всех причин', 'source': 'Чехов. Рассказ неизвестного человека'}], 'abbr': ['разг', 'экспрес'], 'meaning': 'Видеть главное в чём-либо, вникать в суть дела.', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': [], 'examples': [{'text': 'Пугачёв был умный мужик и смотрел в корень бей бар и господ, а после, мол, разберёмся, что к чему!', 'source': 'Л. Соболев, Капитальный ремонт'}]}, {'dictionary': 'Volkova', 'role': [], 'meaning': 'Вникать в существо дела.', 'abbr': ['разг', 'фам'], 'examples': [{'text': 'Всегда надо смотреть в корень.', 'source': ''}]}]}
#
#
# -- 8700 --
# Last idiom to be processed:
# {'phrase': ['сколь потопать то и полопать'], 'semantics': [{'examples': [{'text': 'И мы тут же решили: завтра прямо в лабазах проведём собрание и утвердим раз и навсегда принцип оплаты по труду. Жизнь-то крестьянская испокон веков на этом стояла: сколь потопаешь, то и полопаешь', 'source': 'И. Акулов. Касьян Остудный'}], 'abbr': ['обл', 'экспрес'], 'meaning': 'Получишь в зависимости от затраченного труда.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8800 --
# Last idiom to be processed:
# {'phrase': ['семь пот сходить', 'семь пот сходить', 'семь пот сходить с'], 'semantics': [{'examples': [{'text': 'Да, оказывается, и эта работёнка — наводить разруху на деревне — кое-какой сноровки требует. Крепко старики строили — пока бревно от сруба оторвёшь, семь потов с тебя сойдёт', 'source': 'Ф. Абрамов. Две зимы и три лета'}, {'text': 'Уже к завтраку с косарей сошло семь потов… Одни молча воткнули косовища в землю, другие ещё докашивали ряды и по одному сходились к ельнику', 'source': 'В. Быков. Знак беды'}], 'abbr': ['прост', 'экспрес'], 'meaning': 'О затрате больших усилий, труда (обычно на тяжёлой работе).', 'role': ['с кого'], 'dictionary': 'Fedorov'}, {'examples': [], 'abbr': ['разг', 'экспрес'], 'meaning': 'Кто-либо затратил огромные усилия в напряжённой работе.', 'role': ['с кого'], 'dictionary': 'Fedorov'}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'О крайнем напряжении, крайних усилиях, приложенных кем-либо для выполнения, осуществления чего-либо.', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': ['с кого'], 'meaning': '', 'abbr': ['прост'], 'examples': [{'text': 'Этот последний бродок тоже был не приведи господь. Жижа, что овсяный кисель и ногу не держит и поплыть не даёт. Пока её распихаешь, чтоб вперёд продвинуться, семь потов сойдёт.', 'source': 'Б. Васильев, А зори здесь тихие...'}]}, {'dictionary': 'Volkova', 'role': ['кого'], 'meaning': 'Изнурился на тяжелой работе.', 'abbr': ['разг', 'перен'], 'examples': []}]}
#
#
# -- 8900 --
# Last idiom to be processed:
# {'phrase': ['свинья в ермолка'], 'semantics': [{'examples': [{'text': 'Смирнов и Балабайкин — какие это актёры? Это бездарности, свиньи в ермолке, тупицы', 'source': 'Чехов. Бумажник'}], 'abbr': ['прост', 'презрит'], 'meaning': 'О чванливом человеке с большими претензиями, ничем не обоснованными.', 'dictionary': 'Fedorov'}]}
#
#
# -- 9000 --
# Last idiom to be processed:
# {'phrase': ['салфет ваш милость'], 'semantics': [{'examples': [{'text': 'Чихнул губернатор. Встали и поклон отдали… И все в один голос сказали: — Салфет вашей милости', 'source': 'Мельников-Печерский. Старые годы'}, {'text': 'Салфет вашей милости, Елена Дмитриевна! — приветствовал её чиханье мужской голос', 'source': 'П. Небольсин. Заметки на пути из Петербурга в Барнаул'}], 'abbr': ['устар', 'прост'], 'meaning': 'Выражение приветствия или доброго пожелания, употреблявшееся в значении: будьте здоровы.', 'dictionary': 'Fedorov'}]}
#
#
# -- 9100 --
# Last idiom to be processed:
# {'phrase': ['с повинный голова головушка'], 'semantics': [{'examples': [{'text': 'Если б… Иван Петрович явился к нему с повинной головой и бросился ему в ноги, он бы, пожалуй, помиловал его', 'source': 'Тургенев. Дворянское гнездо'}, {'text': 'Согрешил, прогневил я государя, куда же мне теперь идти с своею повинною головушкой, где смогу я искупить свою вину?', 'source': 'В. Костылев. Иван Грозный'}], 'meaning': 'Раскаиваясь в чём-либо, признавая себя виновным (приходить, являться).', 'dictionary': 'Fedorov', 'abbr': []}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10020/1949478261.py in <module>
#       1 idioms = get_idioms()
# ----> 2 idioms_lem = lemmatize_idioms(idioms)
#
# ~\AppData\Local\Temp/ipykernel_10020/3836682423.py in lemmatize_idioms(idioms)
#      45         idioms_lem.append({'phrase': []})
#      46         for phrase in idiom['phrase']:
# ---> 47             idioms_lem[-1]['phrase'].append(' '.join(parse(phrase)))
#      48         idioms_lem[-1].update({key: value for key, value in idiom.items() if key != 'phrase'})
#      49         if i % 100 == 0 and i > 0:
#
# ~\AppData\Local\Temp/ipykernel_10020/3836682423.py in parse(text)
#      12 def parse(text):
#      13     tokens = []
# ---> 14     result = Mystem().analyze(text)
#      15
#      16     for i, word in enumerate(result):
#
# D:\anaconda\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     253         result = []
#     254         for line in text.splitlines():
# --> 255             result.extend(self._analyze_impl(line))
#     256         return result
#     257
#
# D:\anaconda\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     316             self._procin.write(_NL)
#     317
# --> 318             out, _ = self._proc.communicate()
#     319             self._proc = None
#     320             try:
#
# D:\anaconda\lib\subprocess.py in communicate(self, input, timeout)
#     962
#     963             try:
# --> 964                 stdout, stderr = self._communicate(input, endtime, timeout)
#     965             except KeyboardInterrupt:
#     966                 # https://bugs.python.org/issue25942
#
# D:\anaconda\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1294             # calls communicate again.
#    1295             if self.stdout is not None:
# -> 1296                 self.stdout_thread.join(self._remaining_time(endtime))
#    1297                 if self.stdout_thread.is_alive():
#    1298                     raise TimeoutExpired(self.args, orig_timeout)
#
# D:\anaconda\lib\threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# D:\anaconda\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# -- 9100 --

# %%
with open(r"D:\Python\diploma\idioms_lemmatized_charm.json", 'r', encoding='utf-8') as f:
        idioms_lem_charm = json.load(f)
len(idioms_lem_charm)
# Out:
# 7800

# %%
for i, idiom in enumerate(idioms):
    if i in range(7999):
        continue
    
    idiom_cur = {'phrase': []}
    for phrase in idiom['phrase']:
        idiom_cur['phrase'].append(' '.join(parse(phrase)))
    idiom_cur.update({key: value for key, value in idiom.items() if key != 'phrase'})
    
    if idiom_cur in idioms_lem_charm:
        print('in first part', idiom_cur['phrase'])
        continue
    
    if idiom_cur in idioms_lem_jup:
        print('in other part')
        idioms_lem_charm.extend(idioms_lem_jup[::-1])
        print('total length ', len(idioms_lem_charm))
        break
    
    idioms_lem_charm.append(idiom_cur)
    
    if i % 100 == 0 and i > 0:
        print(f'-- {i} --\nLast idiom to be processed:\n{idioms_lem_charm[-1]}\n\n')
        #dump_idioms(idioms_lem[-100:])
# Out:
# in first part ['приводить на память']
# in first part ['приводить в божеский вид']
# -- 8100 --
# Last idiom to be processed:
# {'phrase': ['про и контра'], 'semantics': [{'examples': [], 'abbr': ['книжн'], 'meaning': 'То, что подтверждает что-либо в сопоставлении с тем, что отрицает его.', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['книжн', 'лат'], 'examples': []}]}
#
#
# -- 8200 --
# Last idiom to be processed:
# {'phrase': ['просклонять во весь падеж', 'склонять во весь падеж', 'просклонять на весь лад', 'склонять на весь лад'], 'semantics': [{'examples': [{'text': 'В этой связи во всех падежах просклоняли Лонк де Лоббеля с его проектом железной дороги Канск — Аляска', 'source': 'С. Сартаков. Хребты Саянские'}], 'abbr': ['разг', 'шутл'], 'meaning': 'Часто упоминать, осуждая, упрекая, критикуя и т. п.', 'role': ['кого, что'], 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': ['кого, что'], 'meaning': '', 'abbr': ['разг'], 'examples': [{'text': 'И вот теперь его склоняли по всем падежам, на всех собраниях, до того дело дошло, что он даже опять похудел.', 'source': 'В. Белов, Привычное дело'}]}, {'examples': [], 'abbr': ['разг', 'экспрес'], 'meaning': '(н. вирта. вечерний звон).', 'role': ['кого, что', 'кого, что. Она внимательно слушает адвоката, и усмешка появляется на её губах всякий раз, как только Лужковский начинает на все лады склонять имя Фрешера'], 'dictionary': 'Fedorov'}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'Часто упоминать, называть (какое-либо слово) или много говорить о ком-либо, чем-либо.', 'abbr': [], 'examples': []}]}
#
#
# -- 8300 --
# Last idiom to be processed:
# {'phrase': ['путеводный звезда'], 'semantics': [{'examples': [{'text': 'Я счастлив, Марианна, тем, что я начинаю эту новую жизнь с тобою вместе! Ты будешь моей путеводной звездой, моей поддержкой', 'source': 'Тургенев. Новь'}], 'abbr': ['восторж'], 'meaning': 'Человек, определяющий своей деятельностью, помощью и т. п. чью-либо жизнь, деятельность.', 'dictionary': 'Fedorov'}, {'examples': [], 'abbr': ['восторж'], 'meaning': 'То, что направляет, определяет чью-либо жизнь, деятельность.', 'dictionary': 'Fedorov'}, {'examples': [], 'abbr': ['восторж'], 'meaning': ': словарь современного русского литературного языка. — м.; л., 1961. — т. 2. — с. 1746.', 'dictionary': 'Fedorov'}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'О том, кто (или что) направляет, определяет чью-либо жизнь, деятельность (первоначально о звезде, указавшей, по библейской легенде, волхвам путь к месту рождения иисуса христа).', 'abbr': [], 'examples': []}, {'dictionary': 'Kveselevich', 'role': [], 'meaning': '', 'abbr': ['высок'], 'examples': [{'text': 'Я счастлив, Марианна, тем, что я начинаю эту новую жизнь с тобою вместе! Ты будешь моей путеводной звездой, моей поддержкой.', 'source': 'И. Тургенев, Новь'}]}]}
#
#
# -- 8400 --
# Last idiom to be processed:
# {'phrase': ['разливаться соловей соловушка'], 'semantics': [{'examples': [{'text': 'Телеграфист и секретарь сельсоветамолчат оба, а она соловушкой разливается и про то и про сё, и про город, и про театры, и про писателей, и про школу', 'source': 'Б. Лавренёв. Воздушная мета'}, {'text': '«Помнишь, — писал Пётр, — я недоверчиво посматривал на тебя, когда ты в первый год своего студенчества соловьем разливался, расхваливая столицу»', 'source': 'А. Лебеденко. Тяжёлый дивизион'}], 'abbr': ['разг', 'иpoн'], 'meaning': 'Говорить с излишним увлечением о чём-либо незначительном.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8500 --
# Last idiom to be processed:
# {'phrase': ['рвать на голова волос'], 'semantics': [{'examples': [{'text': 'Федот Федотыч рвал на голове волосы, проклиная себя за то, что не продал хлеб откупщику', 'source': 'И. Акулов. Касьян Остудный'}], 'abbr': ['разг', 'экспрес'], 'meaning': 'Приходить в отчаяние; горевать; испытывать досаду.', 'dictionary': 'Fedorov'}]}
#
#
# -- 8600 --
# Last idiom to be processed:
# {'phrase': ['рябить в глаз', 'рябь в глаз'], 'semantics': [{'examples': [{'text': 'Годунов:Я словно в бездну тёмную гляжу! Рябит в глазах и путаются мысли', 'source': 'А. К. Толстой. Смерть Иоанна Грозного'}, {'text': 'Перед летками ульев рябили на глазах… играющие пчёлы и трутни', 'source': 'Л. Н. Толстой. Анна Каренина'}], 'abbr': ['разг'], 'meaning': 'Быстро сменяясь, мелькает, пестрит при восприятии зрением.', 'dictionary': 'Fedorov'}, {'dictionary': 'Kveselevich', 'role': ['у кого'], 'meaning': '', 'abbr': [], 'examples': []}, {'dictionary': 'Fedosov', 'role': [], 'meaning': 'Ощущении пестроты, мелькающих то-чек, пятнышек перед глазами.', 'abbr': [], 'examples': []}]}
#
#
# -- 8700 --
# Last idiom to be processed:
# {'phrase': ['с молодой зуб'], 'semantics': [{'examples': [{'text': 'А мне не нужна Егорова прибыль!.', 'source': '— .'}, {'text': 'с какой-то нутряной тоской кричит Семён. — Пусть Егор где хоть командствует, на земле я сам себе голова. Я в Конькове с молодых зубов первым хозяином был и в поддужные к нему не пойду!', 'source': 'Ю. Нагибин. Трудный путь'}], 'abbr': ['прост', 'экспрес'], 'meaning': 'Смолоду, с ранних лет.', 'dictionary': 'Fedorov'}]}
#
#
# in other part
# total length  17345

# %%
len(idioms)
# Out:
# 17847

# %%
len(idioms_lem_charm)
# Out:
# 17346

# %%
len(idioms_lem_charm)
# Out:
# 17346

# %%
with open(r"D:\Python\diploma\idioms_lemmatized.json", 'w', encoding='utf-8') as f:
    json.dump(idioms_lem_charm, f, ensure_ascii=False, indent=4)

# %%
with open(r"D:\Python\diploma\idioms_lemmatized.json", 'r', encoding='utf-8') as f:
    idioms_lem_charm = json.load(f)
len(idioms_lem_charm)
# Out:
# 17346

# %%
all_sems = []
for phrase in idioms_lem_charm:
    all_sems.append(phrase['semantics'])
len(all_sems)
# Out:
# 17346

# %%
idioms = get_idioms()

# %%
i = 0
for idiom in idioms:
    i += 1
    
    if i % 500 == 0:
        print(i, ' Milestone passed')
        
    if idiom['semantics'] in all_sems:
        continue
    
    idiom_cur = {'phrase': []}
    for phrase in idiom['phrase']:
        idiom_cur['phrase'].append(' '.join(parse(phrase)))
    idiom_cur.update({key: value for key, value in idiom.items() if key != 'phrase'})
    
    if idiom_cur in idioms_lem_charm:
        continue
    
    idioms_lem_charm.append(idiom_cur)
    
    if len(idioms_lem_charm) == len(idioms):
        print('Reached wanted length')
        break

len(idioms_lem_charm)
# Out:
# 500  Milestone passed
# 1000  Milestone passed
# 1500  Milestone passed
# 2000  Milestone passed
# 2500  Milestone passed
# 3000  Milestone passed
# 3500  Milestone passed
# 4000  Milestone passed
# 4500  Milestone passed
# 5000  Milestone passed
# 5500  Milestone passed
# 6000  Milestone passed
# 6500  Milestone passed
# 7000  Milestone passed
# 7500  Milestone passed
# 8000  Milestone passed
# 8500  Milestone passed
# 9000  Milestone passed
# 9500  Milestone passed
# 10000  Milestone passed
# 10500  Milestone passed
# 11000  Milestone passed
# 11500  Milestone passed
# 12000  Milestone passed
# 12500  Milestone passed
# 13000  Milestone passed
# 13500  Milestone passed
# 14000  Milestone passed
# 14500  Milestone passed
# 15000  Milestone passed
# 15500  Milestone passed
# 16000  Milestone passed
# 16500  Milestone passed
# 17000  Milestone passed
# 17500  Milestone passed
# 17844

# %%
len(idioms)
# Out:
# 17847

# %%
with open(r"D:\Python\diploma\idioms_lemmatized.json", 'w', encoding='utf-8') as f:
    json.dump(idioms_lem_charm, f, ensure_ascii=False, indent=4)
