# %%
import os
from pathlib import Path
import shutil
from pymystem3 import Mystem

# %%
def parse(text):
    tokens = []
    result = Mystem().analyze(text)

    for i, word in enumerate(result):
        if not word.get('analysis', 0) or not word.get('text', 0):
            continue

        word_base = word['analysis'][0]
        if not word_base.get('lex', 0) or not word_base.get('gr', 0):
            continue

        tokens.append(word['analysis'][0]['lex'])
    return tokens

# %%
def lenta_reader(path_in, path_out, start=6987):
    text_length = 0
    file_ind = start
    i = 0
    
    for file in Path(path_in).glob('*.txt'):
        i += 1
        if '.csv' in str(file):
            continue

        cur_text = []
        with open(file, 'r', encoding='utf-8') as f:
            for line in f.readlines():
                if '# text =' in line:
                    if line[9] == '#':
                        continue
                    cur_text.append(line.split(' = ')[-1]+' ')

        text_parsed = parse(''.join(cur_text))
        text_length += len(text_parsed)

        article_txt_name = "{}_processed.txt".format(file_ind)
        with open(os.path.join(path_out, article_txt_name), 'w', encoding='utf-8') as file_out:
            file_out.write(' '.join(text_parsed))
        file_ind -= 1

        if i % 50 == 0:
            print('Curent article: ', 6987-file_ind, '\nCorpus length: ', text_length)
        
        if text_length >= 250000:
            break

    print('Folder: ', path_in, '\nCorpus gain: ', text_length)
    return file_ind, text_length

# %%
#PROJECT_ROOT = os.path.dirname(os.path.realpath(__file__))
#ASSETS_PATH = os.path.join(PROJECT_ROOT, 'news_clean')
#prepare_environment(ASSETS_PATH)

corpus_length = 0

start_id, length = lenta_reader('texts_tagged_lenta', 'news_clean')
print('\tCURRENT CORPUS LENGTH: ', corpus_length, '\n\tN OF ARTICLES: ', 6987-start_id)
corpus_length += length

print('\n\nTotal corus length: ', corpus_length, '\nNumber of articles: ', 6987-start_id)
# Out:
# Curent article:  50
# Corpus length:  7063
# Curent article:  100
# Corpus length:  14280
# Curent article:  150
# Corpus length:  21859
# Curent article:  200
# Corpus length:  29593
# Curent article:  250
# Corpus length:  36723
# Curent article:  300
# Corpus length:  45040
# Curent article:  350
# Corpus length:  53085
# Curent article:  400
# Corpus length:  61001
# Curent article:  450
# Corpus length:  69869
# Curent article:  500
# Corpus length:  78693
# Curent article:  550
# Corpus length:  87199
# Curent article:  600
# Corpus length:  95890
# Curent article:  650
# Corpus length:  104538
# Curent article:  700
# Corpus length:  113104
# Curent article:  750
# Corpus length:  122432
# Curent article:  800
# Corpus length:  132400
# Curent article:  850
# Corpus length:  142023
# Curent article:  900
# Corpus length:  151323
# Curent article:  950
# Corpus length:  160264
# Curent article:  1000
# Corpus length:  169208
# Curent article:  1050
# Corpus length:  177954
# Curent article:  1100
# Corpus length:  186795
# Curent article:  1150
# Corpus length:  194899
# Curent article:  1200
# Corpus length:  203550
# Curent article:  1250
# Corpus length:  213287
# Curent article:  1300
# Corpus length:  221647
# Curent article:  1350
# Corpus length:  228893
# Curent article:  1400
# Corpus length:  237030
# Curent article:  1450
# Corpus length:  244859
# Folder:  texts_tagged_lenta
# Corpus gain:  250273
# 	CURRENT CORPUS LENGTH:  0
# 	N OF ARTICLES:  1483
#
#
# Total corus length:  250273
# Number of articles:  1483
